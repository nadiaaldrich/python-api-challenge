# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat = []
lng = []
temp = []
cloudiness = []
country = []
date = []
humidity = []
temp_max = []
wind_speed = []
city_name = []

# %%
# set up lists to hold reponse info
# records = 0-50
# sets = 1-15,,
record_counter = 0
set_counter = 0
records = []
sets = []

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

print(f"-----------------------------")
print(f"Beginning Data Retrieval")
print(f"-----------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
# Build partial query URL
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    response = requests.get(query_url + city).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0
    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))

    
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response['name'])
        
    except:
        print(f"City not found.")
        pass
    
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 0 | cape town
# Processing record 2 of set 0 | cabo san lucas
# Processing record 3 of set 0 | gebre guracha
# Processing record 4 of set 0 | bredasdorp
# Processing record 5 of set 0 | punta arenas
# Processing record 6 of set 0 | olean
# Processing record 7 of set 0 | axixa do tocantins
# City not found.
# Processing record 8 of set 0 | ushuaia
# Processing record 9 of set 0 | taolanaro
# City not found.
# Processing record 10 of set 0 | longyan
# Processing record 11 of set 0 | mataura
# Processing record 12 of set 0 | trebisov
# Processing record 13 of set 0 | rikitea
# Processing record 14 of set 0 | harper
# Processing record 15 of set 0 | covington
# Processing record 16 of set 0 | karratha
# Processing record 17 of set 0 | berdigestyakh
# Processing record 18 of set 0 | ambulu
# Processing record 19 of set 0 | tumannyy
# City not found.
# Processing record 20 of set 0 | olafsvik
# Processing record 21 of set 0 | busselton
# Processing record 22 of set 0 | saint-augustin
# Processing record 23 of set 0 | lensk
# Processing record 24 of set 0 | tabou
# Processing record 25 of set 0 | jitia
# Processing record 26 of set 0 | new norfolk
# Processing record 27 of set 0 | tasiilaq
# Processing record 28 of set 0 | hirado
# Processing record 29 of set 0 | avarua
# Processing record 30 of set 0 | iqaluit
# Processing record 31 of set 0 | pevek
# Processing record 32 of set 0 | grand river south east
# City not found.
# Processing record 33 of set 0 | karlskrona
# Processing record 34 of set 0 | paso del toro
# Processing record 35 of set 0 | fortuna
# Processing record 36 of set 0 | port-gentil
# Processing record 37 of set 0 | airai
# Processing record 38 of set 0 | yunhe
# Processing record 39 of set 0 | barrow
# Processing record 40 of set 0 | hermanus
# Processing record 41 of set 0 | butaritari
# Processing record 42 of set 0 | alihe
# Processing record 43 of set 0 | lolua
# City not found.
# Processing record 44 of set 0 | jamestown
# Processing record 45 of set 0 | oiba
# Processing record 46 of set 0 | illoqqortoormiut
# City not found.
# Processing record 47 of set 0 | kapoeta
# Processing record 48 of set 0 | ilulissat
# Processing record 49 of set 0 | jalu
# Processing record 50 of set 0 | port alfred
# Processing record 0 of set 1 | batticaloa
# Processing record 1 of set 1 | tacoronte
# Processing record 2 of set 1 | vaini
# Processing record 3 of set 1 | same
# Processing record 4 of set 1 | jizan
# Processing record 5 of set 1 | soloneshnoye
# Processing record 6 of set 1 | lagoa
# Processing record 7 of set 1 | kurumkan
# Processing record 8 of set 1 | castro
# Processing record 9 of set 1 | nouadhibou
# Processing record 10 of set 1 | shingu
# Processing record 11 of set 1 | richards bay
# Processing record 12 of set 1 | saint-philippe
# Processing record 13 of set 1 | san quintin
# Processing record 14 of set 1 | mys shmidta
# City not found.
# Processing record 15 of set 1 | sambava
# Processing record 16 of set 1 | cocachacra
# Processing record 17 of set 1 | belmonte
# Processing record 18 of set 1 | elban
# Processing record 19 of set 1 | gravelbourg
# Processing record 20 of set 1 | port hedland
# Processing record 21 of set 1 | smithers
# Processing record 22 of set 1 | solsvik
# City not found.
# Processing record 23 of set 1 | puerto ayora
# Processing record 24 of set 1 | souillac
# Processing record 25 of set 1 | normandin
# Processing record 26 of set 1 | chuy
# Processing record 27 of set 1 | tokur
# Processing record 28 of set 1 | port blair
# Processing record 29 of set 1 | phan rang
# City not found.
# Processing record 30 of set 1 | ribeira grande
# Processing record 31 of set 1 | kiunga
# Processing record 32 of set 1 | gazni
# City not found.
# Processing record 33 of set 1 | bambous virieux
# Processing record 34 of set 1 | kodiak
# Processing record 35 of set 1 | carnarvon
# Processing record 36 of set 1 | barentsburg
# City not found.
# Processing record 37 of set 1 | karaton
# Processing record 38 of set 1 | nizhneyansk
# City not found.
# Processing record 39 of set 1 | brae
# Processing record 40 of set 1 | alugan
# Processing record 41 of set 1 | kapaa
# Processing record 42 of set 1 | jumla
# Processing record 43 of set 1 | along
# Processing record 44 of set 1 | canon city
# Processing record 45 of set 1 | atuona
# Processing record 46 of set 1 | namibe
# Processing record 47 of set 1 | faanui
# Processing record 48 of set 1 | berlevag
# Processing record 49 of set 1 | port hardy
# Processing record 50 of set 1 | belushya guba
# City not found.
# Processing record 0 of set 2 | hilo
# Processing record 1 of set 2 | beloha
# Processing record 2 of set 2 | kashi
# Processing record 3 of set 2 | nanortalik
# Processing record 4 of set 2 | riyadh
# Processing record 5 of set 2 | qaqortoq
# Processing record 6 of set 2 | adrar
# Processing record 7 of set 2 | srivardhan
# Processing record 8 of set 2 | dikson
# Processing record 9 of set 2 | tuktoyaktuk
# Processing record 10 of set 2 | inta
# Processing record 11 of set 2 | hvide sande
# Processing record 12 of set 2 | sibu
# Processing record 13 of set 2 | torbay
# Processing record 14 of set 2 | samusu
# City not found.
# Processing record 15 of set 2 | derby
# Processing record 16 of set 2 | kaitangata
# Processing record 17 of set 2 | namatanai
# Processing record 18 of set 2 | marcona
# City not found.
# Processing record 19 of set 2 | marsh harbour
# Processing record 20 of set 2 | peniche
# Processing record 21 of set 2 | saint george
# Processing record 22 of set 2 | neuquen
# Processing record 23 of set 2 | salinas
# Processing record 24 of set 2 | umzimvubu
# City not found.
# Processing record 25 of set 2 | hithadhoo
# Processing record 26 of set 2 | verkh-usugli
# Processing record 27 of set 2 | abha
# Processing record 28 of set 2 | grand gaube
# Processing record 29 of set 2 | mullovka
# Processing record 30 of set 2 | tsihombe
# City not found.
# Processing record 31 of set 2 | nichlaul
# Processing record 32 of set 2 | dingle
# Processing record 33 of set 2 | roches noires
# City not found.
# Processing record 34 of set 2 | darhan
# Processing record 35 of set 2 | saleaula
# City not found.
# Processing record 36 of set 2 | rawson
# Processing record 37 of set 2 | san patricio
# Processing record 38 of set 2 | huangnihe
# Processing record 39 of set 2 | mapastepec
# Processing record 40 of set 2 | bangkal
# Processing record 41 of set 2 | whitehorse
# Processing record 42 of set 2 | hobart
# Processing record 43 of set 2 | qaanaaq
# Processing record 44 of set 2 | mar del plata
# Processing record 45 of set 2 | port elizabeth
# Processing record 46 of set 2 | hambantota
# Processing record 47 of set 2 | constitucion
# Processing record 48 of set 2 | byron bay
# Processing record 49 of set 2 | arraial do cabo
# Processing record 50 of set 2 | wladyslawowo
# Processing record 0 of set 3 | kempsey
# Processing record 1 of set 3 | azimur
# City not found.
# Processing record 2 of set 3 | broome
# Processing record 3 of set 3 | kovylkino
# Processing record 4 of set 3 | midland
# Processing record 5 of set 3 | exeter
# Processing record 6 of set 3 | portland
# Processing record 7 of set 3 | cairns
# Processing record 8 of set 3 | batagay-alyta
# Processing record 9 of set 3 | kruisfontein
# Processing record 10 of set 3 | luba
# Processing record 11 of set 3 | walvis bay
# Processing record 12 of set 3 | erzin
# Processing record 13 of set 3 | matay
# Processing record 14 of set 3 | albany
# Processing record 15 of set 3 | bandarbeyla
# Processing record 16 of set 3 | grindavik
# Processing record 17 of set 3 | klyuchi
# Processing record 18 of set 3 | geraldton
# Processing record 19 of set 3 | maragogi
# Processing record 20 of set 3 | havoysund
# Processing record 21 of set 3 | launceston
# Processing record 22 of set 3 | melfi
# Processing record 23 of set 3 | ponta do sol
# Processing record 24 of set 3 | puerto escondido
# Processing record 25 of set 3 | mirabad
# Processing record 26 of set 3 | kegayli
# City not found.
# Processing record 27 of set 3 | bhongir
# Processing record 28 of set 3 | port augusta
# Processing record 29 of set 3 | west wendover
# Processing record 30 of set 3 | elizabeth city
# Processing record 31 of set 3 | hay river
# Processing record 32 of set 3 | labuhan
# Processing record 33 of set 3 | lazaro cardenas
# Processing record 34 of set 3 | mount gambier
# Processing record 35 of set 3 | georgetown
# Processing record 36 of set 3 | leningradskiy
# Processing record 37 of set 3 | kamenskoye
# City not found.
# Processing record 38 of set 3 | flinders
# Processing record 39 of set 3 | sao filipe
# Processing record 40 of set 3 | marsa matruh
# Processing record 41 of set 3 | hualmay
# Processing record 42 of set 3 | talnakh
# Processing record 43 of set 3 | quatre cocos
# Processing record 44 of set 3 | tiksi
# Processing record 45 of set 3 | dzhusaly
# City not found.
# Processing record 46 of set 3 | korla
# Processing record 47 of set 3 | riohacha
# Processing record 48 of set 3 | belaya gora
# Processing record 49 of set 3 | bethel
# Processing record 50 of set 3 | xuddur
# Processing record 0 of set 4 | alegrete
# Processing record 1 of set 4 | khatanga
# Processing record 2 of set 4 | yellowknife
# Processing record 3 of set 4 | ambanja
# Processing record 4 of set 4 | bluff
# Processing record 5 of set 4 | upernavik
# Processing record 6 of set 4 | coihaique
# Processing record 7 of set 4 | karaul
# City not found.
# Processing record 8 of set 4 | faya
# Processing record 9 of set 4 | victoria
# Processing record 10 of set 4 | nikolskoye
# Processing record 11 of set 4 | bilma
# Processing record 12 of set 4 | fukue
# Processing record 13 of set 4 | redmond
# Processing record 14 of set 4 | manta
# Processing record 15 of set 4 | hudiksvall
# Processing record 16 of set 4 | banda aceh
# Processing record 17 of set 4 | dmitriyevka
# Processing record 18 of set 4 | moose factory
# Processing record 19 of set 4 | mbandaka
# Processing record 20 of set 4 | naze
# Processing record 21 of set 4 | shenjiamen
# Processing record 22 of set 4 | vila
# Processing record 23 of set 4 | lompoc
# Processing record 24 of set 4 | anadyr
# Processing record 25 of set 4 | saskylakh
# Processing record 26 of set 4 | aguie
# Processing record 27 of set 4 | heliconia
# Processing record 28 of set 4 | smoky lake
# Processing record 29 of set 4 | kijang
# Processing record 30 of set 4 | mandera
# Processing record 31 of set 4 | susurluk
# Processing record 32 of set 4 | pangnirtung
# Processing record 33 of set 4 | san policarpo
# Processing record 34 of set 4 | lebu
# Processing record 35 of set 4 | sinnamary
# Processing record 36 of set 4 | victoria point
# Processing record 37 of set 4 | popondetta
# Processing record 38 of set 4 | alta gracia
# Processing record 39 of set 4 | vaitupu
# City not found.
# Processing record 40 of set 4 | fomboni
# Processing record 41 of set 4 | ilo
# Processing record 42 of set 4 | salalah
# Processing record 43 of set 4 | ust-kan
# Processing record 44 of set 4 | escanaba
# Processing record 45 of set 4 | linxi
# Processing record 46 of set 4 | bafq
# Processing record 47 of set 4 | hobyo
# Processing record 48 of set 4 | antofagasta
# Processing record 49 of set 4 | bud
# Processing record 50 of set 4 | nantucket
# Processing record 0 of set 5 | east london
# Processing record 1 of set 5 | ketchikan
# Processing record 2 of set 5 | bima
# Processing record 3 of set 5 | bereda
# Processing record 4 of set 5 | padang
# Processing record 5 of set 5 | tefe
# Processing record 6 of set 5 | katsuura
# Processing record 7 of set 5 | sabang
# Processing record 8 of set 5 | port hawkesbury
# Processing record 9 of set 5 | jatoi
# City not found.
# Processing record 10 of set 5 | chokurdakh
# Processing record 11 of set 5 | semey
# Processing record 12 of set 5 | shihezi
# Processing record 13 of set 5 | porto seguro
# Processing record 14 of set 5 | vanavara
# Processing record 15 of set 5 | lata
# Processing record 16 of set 5 | mopipi
# Processing record 17 of set 5 | bay roberts
# Processing record 18 of set 5 | campoverde
# Processing record 19 of set 5 | rorvik
# Processing record 20 of set 5 | lowicz
# Processing record 21 of set 5 | thompson
# Processing record 22 of set 5 | ghanzi
# Processing record 23 of set 5 | tiarei
# Processing record 24 of set 5 | pathein
# Processing record 25 of set 5 | yirol
# City not found.
# Processing record 26 of set 5 | oktyabrskoye
# Processing record 27 of set 5 | san ramon
# Processing record 28 of set 5 | middle island
# Processing record 29 of set 5 | salekhard
# Processing record 30 of set 5 | pitmoaga
# Processing record 31 of set 5 | sitka
# Processing record 32 of set 5 | norman wells
# Processing record 33 of set 5 | garowe
# Processing record 34 of set 5 | bengkulu
# Processing record 35 of set 5 | attawapiskat
# City not found.
# Processing record 36 of set 5 | vung tau
# Processing record 37 of set 5 | srednekolymsk
# Processing record 38 of set 5 | viedma
# Processing record 39 of set 5 | alofi
# Processing record 40 of set 5 | rawannawi
# City not found.
# Processing record 41 of set 5 | saldanha
# Processing record 42 of set 5 | marrakesh
# Processing record 43 of set 5 | makokou
# Processing record 44 of set 5 | tomelloso
# Processing record 45 of set 5 | vao
# Processing record 46 of set 5 | akyab
# Processing record 47 of set 5 | tarakan
# Processing record 48 of set 5 | bathsheba
# Processing record 49 of set 5 | samfya
# Processing record 50 of set 5 | guanica
# Processing record 0 of set 6 | tabiauea
# City not found.
# Processing record 1 of set 6 | bolshiye uki
# City not found.
# Processing record 2 of set 6 | porbandar
# Processing record 3 of set 6 | itapeva
# Processing record 4 of set 6 | miri
# Processing record 5 of set 6 | teguise
# Processing record 6 of set 6 | gazanjyk
# Processing record 7 of set 6 | saint anthony
# Processing record 8 of set 6 | meyungs
# City not found.
# Processing record 9 of set 6 | largs
# Processing record 10 of set 6 | wolfenbuttel
# Processing record 11 of set 6 | kahului
# Processing record 12 of set 6 | coxim
# Processing record 13 of set 6 | tampico
# Processing record 14 of set 6 | raudeberg
# Processing record 15 of set 6 | mashhad
# Processing record 16 of set 6 | chone
# Processing record 17 of set 6 | codrington
# Processing record 18 of set 6 | vila franca do campo
# Processing record 19 of set 6 | chagda
# City not found.
# Processing record 20 of set 6 | cockburn town
# Processing record 21 of set 6 | mulchen
# Processing record 22 of set 6 | tilichiki
# Processing record 23 of set 6 | egvekinot
# Processing record 24 of set 6 | independence
# Processing record 25 of set 6 | los llanos de aridane
# Processing record 26 of set 6 | visnes
# Processing record 27 of set 6 | fayaoue
# Processing record 28 of set 6 | toliary
# City not found.
# Processing record 29 of set 6 | umea
# Processing record 30 of set 6 | san rafael
# Processing record 31 of set 6 | ystad
# Processing record 32 of set 6 | breves
# Processing record 33 of set 6 | rizhao
# Processing record 34 of set 6 | esperance
# Processing record 35 of set 6 | tautira
# Processing record 36 of set 6 | sandila
# Processing record 37 of set 6 | naldurg
# Processing record 38 of set 6 | amderma
# City not found.
# Processing record 39 of set 6 | ostrovnoy
# Processing record 40 of set 6 | mnogovershinnyy
# Processing record 41 of set 6 | diu
# Processing record 42 of set 6 | kulob
# Processing record 43 of set 6 | yumen
# Processing record 44 of set 6 | biltine
# Processing record 45 of set 6 | la playona
# Processing record 46 of set 6 | touros
# Processing record 47 of set 6 | sistranda
# Processing record 48 of set 6 | mahebourg
# Processing record 49 of set 6 | vardo
# Processing record 50 of set 6 | bonthe
# Processing record 0 of set 7 | mount abu
# Processing record 1 of set 7 | katherine
# Processing record 2 of set 7 | tunduru
# City not found.
# Processing record 3 of set 7 | rotifunk
# Processing record 4 of set 7 | provideniya
# Processing record 5 of set 7 | coquimbo
# Processing record 6 of set 7 | flin flon
# Processing record 7 of set 7 | cayenne
# Processing record 8 of set 7 | aland
# Processing record 9 of set 7 | boa viagem
# Processing record 10 of set 7 | santa rosa
# Processing record 11 of set 7 | butterworth
# Processing record 12 of set 7 | bari sadri
# Processing record 13 of set 7 | palmares do sul
# Processing record 14 of set 7 | clemmons
# Processing record 15 of set 7 | cidreira
# Processing record 16 of set 7 | riga
# Processing record 17 of set 7 | asau
# Processing record 18 of set 7 | sentyabrskiy
# City not found.
# Processing record 19 of set 7 | alyangula
# Processing record 20 of set 7 | te anau
# Processing record 21 of set 7 | sakakah
# Processing record 22 of set 7 | kisangani
# Processing record 23 of set 7 | voyvozh
# Processing record 24 of set 7 | torit
# Processing record 25 of set 7 | kindu
# Processing record 26 of set 7 | othonoi
# City not found.
# Processing record 27 of set 7 | guerrero negro
# Processing record 28 of set 7 | satitoa
# City not found.
# Processing record 29 of set 7 | jardim
# Processing record 30 of set 7 | luderitz
# Processing record 31 of set 7 | mamallapuram
# Processing record 32 of set 7 | alotau
# City not found.
# Processing record 33 of set 7 | pokhara
# Processing record 34 of set 7 | severo-kurilsk
# Processing record 35 of set 7 | isla mujeres
# Processing record 36 of set 7 | joao camara
# Processing record 37 of set 7 | ranau
# Processing record 38 of set 7 | rio gallegos
# Processing record 39 of set 7 | ilheus
# Processing record 40 of set 7 | anar darreh
# City not found.
# Processing record 41 of set 7 | nizhniy kuranakh
# Processing record 42 of set 7 | lugovoy
# Processing record 43 of set 7 | nome
# Processing record 44 of set 7 | pasighat
# Processing record 45 of set 7 | tocopilla
# Processing record 46 of set 7 | ambon
# Processing record 47 of set 7 | general pico
# Processing record 48 of set 7 | iseyin
# Processing record 49 of set 7 | caranavi
# Processing record 50 of set 7 | kalaleh
# Processing record 0 of set 8 | mogok
# Processing record 1 of set 8 | cabedelo
# Processing record 2 of set 8 | puerto boyaca
# Processing record 3 of set 8 | harboore
# Processing record 4 of set 8 | deputatskiy
# Processing record 5 of set 8 | jacutinga
# Processing record 6 of set 8 | oume
# Processing record 7 of set 8 | macenta
# Processing record 8 of set 8 | phalodi
# Processing record 9 of set 8 | tomatlan
# Processing record 10 of set 8 | bonfim
# Processing record 11 of set 8 | jocotan
# Processing record 12 of set 8 | punto fijo
# Processing record 13 of set 8 | bilibino
# Processing record 14 of set 8 | lac du bonnet
# Processing record 15 of set 8 | bolungarvik
# City not found.
# Processing record 16 of set 8 | soyo
# Processing record 17 of set 8 | sioux lookout
# Processing record 18 of set 8 | louisbourg
# City not found.
# Processing record 19 of set 8 | vilyuysk
# Processing record 20 of set 8 | ballina
# Processing record 21 of set 8 | aden
# Processing record 22 of set 8 | longyearbyen
# Processing record 23 of set 8 | macau
# Processing record 24 of set 8 | yar-sale
# Processing record 25 of set 8 | villa juarez
# Processing record 26 of set 8 | gelnica
# Processing record 27 of set 8 | alenquer
# Processing record 28 of set 8 | sao jose da coroa grande
# Processing record 29 of set 8 | muros
# Processing record 30 of set 8 | laguna
# Processing record 31 of set 8 | ust-tsilma
# Processing record 32 of set 8 | mogadishu
# Processing record 33 of set 8 | palmer
# Processing record 34 of set 8 | biala podlaska
# Processing record 35 of set 8 | mallama
# City not found.
# Processing record 36 of set 8 | wahran
# City not found.
# Processing record 37 of set 8 | sydney
# Processing record 38 of set 8 | tucumcari
# Processing record 39 of set 8 | tuatapere
# Processing record 40 of set 8 | okhotsk
# Processing record 41 of set 8 | ipora
# Processing record 42 of set 8 | graaff-reinet
# Processing record 43 of set 8 | qasigiannguit
# Processing record 44 of set 8 | lakatoro
# Processing record 45 of set 8 | piedras negras
# Processing record 46 of set 8 | ismailia
# Processing record 47 of set 8 | ha
# City not found.
# Processing record 48 of set 8 | kurilsk
# Processing record 49 of set 8 | kamenka
# Processing record 50 of set 8 | plettenberg bay
# Processing record 0 of set 9 | goderich
# Processing record 1 of set 9 | olbia
# Processing record 2 of set 9 | big spring
# Processing record 3 of set 9 | beysehir
# Processing record 4 of set 9 | celestun
# Processing record 5 of set 9 | sataua
# City not found.
# Processing record 6 of set 9 | mizdah
# Processing record 7 of set 9 | mangrol
# Processing record 8 of set 9 | kayanga
# Processing record 9 of set 9 | kouango
# Processing record 10 of set 9 | santa teresa
# Processing record 11 of set 9 | nkhotakota
# Processing record 12 of set 9 | lipin bor
# Processing record 13 of set 9 | mawlaik
# Processing record 14 of set 9 | pochutla
# Processing record 15 of set 9 | cherskiy
# Processing record 16 of set 9 | morondava
# Processing record 17 of set 9 | terra nova
# Processing record 18 of set 9 | huarmey
# Processing record 19 of set 9 | camargo
# Processing record 20 of set 9 | komsomolskiy
# Processing record 21 of set 9 | sur
# Processing record 22 of set 9 | karkaralinsk
# City not found.
# Processing record 23 of set 9 | waipawa
# Processing record 24 of set 9 | yatou
# Processing record 25 of set 9 | chumikan
# Processing record 26 of set 9 | natchitoches
# Processing record 27 of set 9 | vancouver
# Processing record 28 of set 9 | merauke
# Processing record 29 of set 9 | tiznit
# Processing record 30 of set 9 | saint-joseph
# Processing record 31 of set 9 | vestmannaeyjar
# Processing record 32 of set 9 | husavik
# Processing record 33 of set 9 | pervomayskoye
# Processing record 34 of set 9 | pandan
# Processing record 35 of set 9 | zernograd
# Processing record 36 of set 9 | ucluelet
# Processing record 37 of set 9 | baghdad
# Processing record 38 of set 9 | burnie
# Processing record 39 of set 9 | praia da vitoria
# Processing record 40 of set 9 | bang len
# Processing record 41 of set 9 | nemuro
# Processing record 42 of set 9 | polunochnoye
# Processing record 43 of set 9 | mantua
# Processing record 44 of set 9 | maceio
# Processing record 45 of set 9 | kargasok
# Processing record 46 of set 9 | kalmunai
# Processing record 47 of set 9 | pemangkat
# Processing record 48 of set 9 | kieta
# Processing record 49 of set 9 | changji
# Processing record 50 of set 9 | khani
# Processing record 0 of set 10 | grenada
# Processing record 1 of set 10 | bubaque
# Processing record 2 of set 10 | kadykchan
# City not found.
# Processing record 3 of set 10 | labuan
# Processing record 4 of set 10 | blyth
# Processing record 5 of set 10 | sale
# Processing record 6 of set 10 | gat
# Processing record 7 of set 10 | kamaishi
# Processing record 8 of set 10 | coahuayana
# Processing record 9 of set 10 | ponta delgada
# Processing record 10 of set 10 | camocim
# Processing record 11 of set 10 | umm kaddadah
# Processing record 12 of set 10 | benalla
# Processing record 13 of set 10 | kristinehamn
# Processing record 14 of set 10 | kovdor
# Processing record 15 of set 10 | hasaki
# Processing record 16 of set 10 | cardston
# Processing record 17 of set 10 | salinopolis
# Processing record 18 of set 10 | roebourne
# Processing record 19 of set 10 | phalaborwa
# Processing record 20 of set 10 | mount isa
# Processing record 21 of set 10 | terney
# Processing record 22 of set 10 | golcuk
# City not found.
# Processing record 23 of set 10 | north bend
# Processing record 24 of set 10 | nizwa
# Processing record 25 of set 10 | tala
# Processing record 26 of set 10 | alekseyevka
# Processing record 27 of set 10 | milkovo
# Processing record 28 of set 10 | kondinskoye
# Processing record 29 of set 10 | orlandia
# Processing record 30 of set 10 | jiddah
# City not found.
# Processing record 31 of set 10 | kiama
# Processing record 32 of set 10 | bontang
# Processing record 33 of set 10 | kapit
# Processing record 34 of set 10 | diffa
# Processing record 35 of set 10 | broken hill
# Processing record 36 of set 10 | vetluzhskiy
# Processing record 37 of set 10 | hun
# Processing record 38 of set 10 | chipinge
# Processing record 39 of set 10 | urazovka
# Processing record 40 of set 10 | vallenar
# Processing record 41 of set 10 | lobito
# Processing record 42 of set 10 | beringovskiy
# Processing record 43 of set 10 | sao felix do xingu
# Processing record 44 of set 10 | patos
# Processing record 45 of set 10 | lavrentiya
# Processing record 46 of set 10 | acajutla
# Processing record 47 of set 10 | narsaq
# Processing record 48 of set 10 | ishigaki
# Processing record 49 of set 10 | tucuma
# Processing record 50 of set 10 | caravelas
# Processing record 0 of set 11 | sobolevo
# Processing record 1 of set 11 | itarema
# Processing record 2 of set 11 | felidhoo
# City not found.
# Processing record 3 of set 11 | oussouye
# Processing record 4 of set 11 | gopalpur
# Processing record 5 of set 11 | wanning
# Processing record 6 of set 11 | marystown
# Processing record 7 of set 11 | fairbanks
# Processing record 8 of set 11 | boditi
# Processing record 9 of set 11 | warrnambool
# Processing record 10 of set 11 | kalemie
# Processing record 11 of set 11 | steinbach
# Processing record 12 of set 11 | pacific grove
# Processing record 13 of set 11 | dordrecht
# Processing record 14 of set 11 | teya
# Processing record 15 of set 11 | bayji
# Processing record 16 of set 11 | tchollire
# Processing record 17 of set 11 | halalo
# City not found.
# Processing record 18 of set 11 | andenes
# Processing record 19 of set 11 | ust-nera
# Processing record 20 of set 11 | fort nelson
# Processing record 21 of set 11 | maniitsoq
# Processing record 22 of set 11 | nadym
# Processing record 23 of set 11 | charlestown
# Processing record 24 of set 11 | rio grande
# Processing record 25 of set 11 | sorland
# Processing record 26 of set 11 | solnechnyy
# Processing record 27 of set 11 | kavieng
# Processing record 28 of set 11 | atambua
# Processing record 29 of set 11 | ornskoldsvik
# Processing record 30 of set 11 | marawi
# Processing record 31 of set 11 | gazli
# Processing record 32 of set 11 | luau
# Processing record 33 of set 11 | dawei
# Processing record 34 of set 11 | kushiro
# Processing record 35 of set 11 | mackay
# Processing record 36 of set 11 | witu
# Processing record 37 of set 11 | port pirie
# Processing record 38 of set 11 | port lincoln
# Processing record 39 of set 11 | belokurikha
# Processing record 40 of set 11 | galgani
# City not found.
# Processing record 41 of set 11 | college
# Processing record 42 of set 11 | salisbury
# Processing record 43 of set 11 | clyde river
# Processing record 44 of set 11 | nyimba
# Processing record 45 of set 11 | toamasina
# Processing record 46 of set 11 | chase
# Processing record 47 of set 11 | puerto colombia
# Processing record 48 of set 11 | binga
# Processing record 49 of set 11 | necochea
# Processing record 50 of set 11 | kysyl-syr
# Processing record 0 of set 12 | porto santo
# Processing record 1 of set 12 | fairhope
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
                "Date": date,
                "City": cities,
                "Country": country,
                "Latitude": lat,
                "Longitude": lng,
                "Max Temp": temp_max,
                "Cloudiness": cloudiness,
                "Humidity": humidity,
                "Wind Speed": wind_speed
                }
weather_data = pd.DataFrame({k: pd.Series(l) for k, l in weather_dict.items()})
weather_data.head()

humidity.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f22532ccaa5c> in <module>
#      13 weather_data.head()
#      14
# ---> 15 humidity.show()
#
# AttributeError: 'list' object has no attribute 'show'

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
